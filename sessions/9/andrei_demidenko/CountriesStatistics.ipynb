# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
data = pd.read_csv('countries.csv')

# %%
data.nlargest(10, 'Population')
# Out:
#             Country                               Region  Population  \
# 42           China         ASIA (EX. NEAR EAST)           1313973713
# 94           India         ASIA (EX. NEAR EAST)           1095351995
# 214  United States   NORTHERN AMERICA                      298444215
# 95       Indonesia         ASIA (EX. NEAR EAST)            245452739
# 27          Brazil               LATIN AMER. & CARIB       188078227
# 156       Pakistan         ASIA (EX. NEAR EAST)            165803560
# 16      Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 169         Russia                  C.W. OF IND. STATES    142893540
# 152        Nigeria   SUB-SAHARAN AFRICA                    131859731
# 103          Japan         ASIA (EX. NEAR EAST)            127463611
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 42          9596960                      136,9                         0,15
# ...

# %%
data.nlargest(10, 'Population').plot('Country', 'Population', kind='bar')

# %%
data.Region.value_counts()
# Out:
# SUB-SAHARAN AFRICA                     51
# LATIN AMER. & CARIB                    45
# WESTERN EUROPE                         28
# ASIA (EX. NEAR EAST)                   28
# OCEANIA                                21
# NEAR EAST                              16
# C.W. OF IND. STATES                    12
# EASTERN EUROPE                         12
# NORTHERN AFRICA                         6
# NORTHERN AMERICA                        5
# BALTICS                                 3
# Name: Region, dtype: int64

# %%
data.Region.value_counts().plot(kind='barh')

# %%
data.sort_values(by=['Area (sq. mi.)'], ascending=False).head(10)
# Out:
#             Country                               Region  Population  \
# 169         Russia                  C.W. OF IND. STATES    142893540
# 36          Canada   NORTHERN AMERICA                       33098932
# 214  United States   NORTHERN AMERICA                      298444215
# 42           China         ASIA (EX. NEAR EAST)           1313973713
# 27          Brazil               LATIN AMER. & CARIB       188078227
# 11       Australia   OCEANIA                                20264082
# 94           India         ASIA (EX. NEAR EAST)           1095351995
# 8        Argentina               LATIN AMER. & CARIB        39921833
# 106     Kazakhstan                  C.W. OF IND. STATES     15233244
# 192          Sudan   SUB-SAHARAN AFRICA                     41236378
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 169        17075200                        8,4                         0,22
# ...

# %%
data.sort_values(by=['Area (sq. mi.)'], ascending=False).head(10).plot('Country','Area (sq. mi.)', kind='barh')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-288c8467c6a2> in <module>
# ----> 1 data.sort_values(by=['Area (sq. mi.)'], ascending=False).head(10).plot('Country','Area (sq. mi.)', kind='barh')
#
# NameError: name 'data' is not defined
